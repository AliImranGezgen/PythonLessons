# %% [markdown]
# OPERATÖRLER <br>
# Karşılaştırma Operatörleri <br>
# <, >, <=, >=, ==, !=<br><br>
#
# Mantıksal Operatörler<br>
# and = ve bağlacı<br>
# or = veya bağlacı<br>
# <br>
# <br>
# in = içinde var mıdır ?<br>
# type = değişkenin türünü gösterir<br>
# str = ToString<br>
#
# evel("") = Gelen ifadeleri matematiksel ifade olarak kabul edip ona göre işlem yapar.<br>
# split() = String cümleyi kelime kelime dizi haline getirir.<br>
# """ """ = 3 tırnak yazılan tüm yazıları olduğu gibi değişkenin içine haspeder.<br>

# %%
100 == 100
14 != 14
15 < 90
16 >= 10
# Out:
# True

# %%
d1 = "Pamuk"; d2 = "Tekir"; d3 = "Metin";
"p" in d1
"etin" in d3
# Out:
# True

# %%
24 >= 20 > 4 == 4 and 45 > 4 > 1 <40 !=5
# Out:
# True

# %%
print(d1,d2,d3,' !')
# Out:
# Pamuk Tekir Metin  !

# %%
dil = " Python "
"Ben en çok" + dil + "dilini seviyorum. <3"
# Out:
# 'Ben en çok Python dilini seviyorum. <3'

# %%
numara = 24390008008
"Benim öğrenci numaram : " + str(numara)
# Out:
# 'Benim öğrenci numaram : 24390008008'

# %%
eval("20*40") + eval("50")
# Out:
# 850

# %%
satir = """Lütfen #@ Yapacağınız İşlemleri
#@yapmadan önce // kontrol ediniz.
"""
satir = satir.replace("#@", "").replace("//", "").upper()
print(satir)
# Out:
# LÜTFEN  YAPACAĞINIZ İŞLEMLERI
# YAPMADAN ÖNCE  KONTROL EDINIZ.

# %%
tekno = "teknolojitutkunu"

# %%
tekno[9:len(tekno)]
tekno[0 : -4]
# Out:
# 'teknolojitut'

# %%
tekno = "ply2t3h4o5n6i7c8"
tekno[1::2]
# Out:
# 'l2345678'

# %%
cumle = "Python eğitimi 101"
cumle.split()
# Out:
# ['Python', 'eğitimi', '101']

# %%
sayilar = [1,2,4]
eval("{2} + {2} + {2}".format(*sayilar))
# Out:
# 12

# %%
sayi = 300/9
f"günün rutin adımları {sayi:.4}"
f"günün rutin adımları {sayi:.4f}"
# Out:
# 'günün rutin adımları 33.3333'
