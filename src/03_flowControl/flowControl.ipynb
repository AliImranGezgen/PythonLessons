# %% [markdown]
# <hr2> Akış Mekanizmaları

# %%
a = 10; b = 25; c = 100; d = ("kedi", "kus", "aslan");

# %%
if a == b:
    print("Dogrudur.")
elif a!=b:
    print("Yanlistir")
else:
    print("Yanlistir")
# Out:
# Yanlistir

# %%
if a <b:   
    print("Harika")
    if c > b:   
        print("Dogru")
# Out:
# Harika
# Dogru

# %%
yas = int(input("yasinizi giriniz :"))
if yas >= 18 :
   if yas <= 30 :
      print("egitime katılabilir.")
else :
      print("egitime katılamaz.")
# Out:
# egitime katılabilir.

# %%
yas1 = int(input("yasinizi giriniz :"))
if yas1 >= 18 and yas1 <= 39:
    print("egitime katilabilir.")
else :
    print("egitime katilamaz.")
# Out:
# egitime katilamaz.

# %%
toplam= [list(range(11)), list(range(10,21)), list(range(20,31))]
kulDeger = int(input("0 ile 30 arasi bir deger giriniz : "))


if kulDeger in toplam[0] : 
    print("1. listenin icinde bulunuyor.")
elif kulDeger in toplam[1] :    
    print("2. listenin icinde bulunuyor.")
else :
    print("3. listenin icinde")
# Out:
# 3. listenin icinde
